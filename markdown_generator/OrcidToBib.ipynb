# %%
orcid = '0000-0003-1934-1000' # Fill your orcid here

# %%
import requests

# %% [markdown]
# We use the `/works` api to list all works related to the orcid. This gives a summary of all works, so citation information is not included. We collect the `put-code` of all works to retrieve the citation information later.

# %%
response = requests.get('https://pub.orcid.org/v3.0/{}/works'.format(orcid),
                        headers={"Accept": "application/orcid+json" })
record = response.json()

# %%
put_codes = []
for work in record['group']:
    put_code = work['work-summary'][0]['put-code']
    put_codes.append(put_code)
put_code = put_codes[0]

# %% [markdown]
# We use the `/<orcid>/work/<put-code>` endpoint to retrieve the citation information for each record.

# %%
citations = []
for put_code in put_codes:
    response = requests.get('https://pub.orcid.org/v3.0/{}/work/{}'.format(orcid, put_code),
                            headers={"Accept": "application/orcid+json" })
    work = response.json()
    if work['citation'] is not None:
        citations.append(work['citation']['citation-value'])

# %%
with open('output.bib', 'w') as bibfile:
    for citation in citations:
        bibfile.write(citation)
        bibfile.write('\n')

# %%
response.json()
# Out:
# {'created-date': {'value': 1718912023558},
#  'last-modified-date': {'value': 1719791239840},
#  'source': {'source-orcid': None,
#   'source-client-id': {'uri': 'https://orcid.org/client/APP-1DSJAQCZ1PW1VN5X',
#    'path': 'APP-1DSJAQCZ1PW1VN5X',
#    'host': 'orcid.org'},
#   'source-name': {'value': 'Web of Science Researcher Profile Sync'},
#   'assertion-origin-orcid': None,
#   'assertion-origin-client-id': None,
#   'assertion-origin-name': None},
#  'put-code': 162023858,
#  'path': '/0000-0003-1934-1000/work/162023858',
#  'title': {'title': {'value': 'PHYSICS-INFORMED NEURAL NETWORKS FOR DEGRADATION DIAGNOSTICS OF LITHIUM-ION BATTERIES'},
#   'subtitle': None,
#   'translated-title': None},
#  'journal-title': {'value': 'PROCEEDINGS OF ASME INTERNATIONAL DESIGN ENGINEERING TECHNICAL CONFERENCES AND COMPUTERS AND INFORMATION IN ENGINEERING CONFERENCE, IDETC-CIE2023, VOL 3A'},
#  'short-description': None,
#  'citation': None,
#  'type': 'journal-article',
#  'publication-date': {'year': {'value': '2023'}, 'month': None, 'day': None},
#  'external-ids': {'external-id': [{'external-id-type': 'doi',
#     'external-id-value': '10.1115/DETC2023-116940',
#     'external-id-normalized': {'value': '10.1115/detc2023-116940',
#      'transient': True},
#     'external-id-normalized-error': None,
#     'external-id-url': {'value': 'https://doi.org/10.1115/DETC2023-116940'},
#     'external-id-relationship': 'self'},
#    {'external-id-type': 'wosuid',
#     'external-id-value': 'WOS:001221579000049',
#     'external-id-normalized': {'value': 'wos:001221579000049',
#      'transient': True},
#     'external-id-normalized-error': None,
#     'external-id-url': {'value': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=Publons&SrcAuth=Publons_CEL&KeyUT=WOS:001221579000049&DestLinkType=FullRecord&DestApp=WOS_CPL'},
#     'external-id-relationship': 'self'}]},
#  'url': {'value': 'https://publons.com/wos-op/publon/65533684/'},
#  'contributors': {'contributor': [{'contributor-orcid': None,
#     'credit-name': {'value': 'Navidi, Sina'},
#     'contributor-email': None,
#     'contributor-attributes': None},
#    {'contributor-orcid': None,
#     'credit-name': {'value': 'Thelen, Adam'},
#     'contributor-email': None,
#     'contributor-attributes': None},
#    {'contributor-orcid': None,
#     'credit-name': {'value': 'Li, Tingkai'},
#     'contributor-email': None,
#     'contributor-attributes': None},
#    {'contributor-orcid': None,
#     'credit-name': {'value': 'Hu, Chao'},
#     'contributor-email': None,
#     'contributor-attributes': None}]},
#  'language-code': None,
#  'country': None,
#  'visibility': 'public'}
